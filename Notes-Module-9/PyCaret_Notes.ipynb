# %% [markdown]
# # PyCaret Notes
# PyCaret is an open-source, low-code ML library to reduce the hypoithesis to insights cycle time in ML experiments. It can replace hundreds of lines of code with only a few, easy to read lines.

# %%
import pandas as pd

# %% [markdown]
# ## Binary Classification

# %%
from pycaret.datasets import get_data #using PyCaret's data repository to load the data in
dataset = get_data('credit')
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1      90000    2          2         2   34      0      0      0      0
# 2      50000    2          2         1   37      0      0      0      0
# 3      50000    1          2         1   57     -1      0     -1      0
# 4      50000    1          1         2   37      0      0      0      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1      0  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 2      0  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 3      0  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
# 4      0  ...    19394.0    19619.0    20024.0    2500.0    1815.0     657.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default
# ...

# %%
#check shape of the data
dataset.shape
# Out:
# (24000, 24)

# %% [markdown]
# In order to demonstrate the predict_model() function on unseen data, a sample of 1200 records has been withheld from the original dataset to be used for predictions. This should not be confused with a train/test split as this particular split is performed to simulate a real life scenario. Another way to think about this is that these 1200 records are not available at the time when the machine learning experiment was performed.

# %%
data = dataset.sample(frac=0.95, random_state=786)
data_unseen = dataset.drop(data.index)
data.reset_index(inplace=True, drop=True)
data_unseen.reset_index(inplace=True, drop=True)
print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (22800, 24)
# Unseen Data For Predictions: (1200, 24)

# %%
from pycaret.classification import *

# setup() function initializes the environment in pycaret and creates the transformation pipeline to prepare the data for modeling and deployment.
# must be called before executing any other function in pycaret
# mandatory parameters: pd dataframe and name of the target col
exp_clf101 = setup(data=data, target='default', session_id=123)
# Out:
# <style  type="text/css" >
#     #T_88f239a0_abde_11ec_9124_aae9fe7ca1d0row44_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_88f239a0_abde_11ec_9124_aae9fe7ca1d0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_88f239a0_abde_11ec_9124_aae9fe7ca1d0level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_88f239a0_abde_11ec_9124_aae9fe7ca1d0row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_88f239a0_abde_11ec_9124_aae9fe7ca1d0row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_88f239a0_abde_11ec_9124_aae9fe7ca1d0level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %% [markdown]
# * Looking above, When setup() is executed, PyCaret's will automatically infer the data types for all features based on certain properties.
# * The data type should be inferred correctly but this is not always the case. To account for this, PyCaret displays a table containing the features and their inferred data types.
# * If all of the data types are correctly identified enter can be pressed to continue or quit can be typed to end the expriment.

# %%
'''
Comparing all models to evaluate performance is a good starting point for modelling once setup is completed.
compare_models() trains all models in the library and scores them using stratified cross validation
TT is training times.
'''
best_model = compare_models()
# Out:
# <style  type="text/css" >
#     #T_a89b131c_abde_11ec_9124_aae9fe7ca1d0 th {
#           text-align: left;
#     }    #T_a89b131c_abde_11ec_9124_aae9fe7ca1d0row0_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_a89b131c_abde_11ec_9124_aae9fe7ca1d0row0_col1 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_a89b131c_abde_11ec_9124_aae9fe7ca1d0row0_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_a89b131c_abde_11ec_9124_aae9fe7ca1d0row0_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_a89b131c_abde_11ec_9124_aae9fe7ca1d0row0_col4 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_a89b131c_abde_11ec_9124_aae9fe7ca1d0row0_col5 {
#             text-align:  left;
# ...

# %%
'''
The grid above is sorted using 'Accuracy' (highest to lowest) which can be changed by passing the sort parameter. 
For example compare_models(sort = 'Recall')
'''
print(best_model)
# Out:
# RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#                 max_iter=None, normalize=False, random_state=123, solver='auto',
#                 tol=0.001)

# %%
#shows all 18 classifiers available in PyCaret
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# lightgbm  Light Gradient Boosting Machine
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# ...

# %% [markdown]
# `create_model` trains and evaluates a model using cross validation, that can be set with the `fold` parameter.

# %% [markdown]
# ### Decision Tree

# %%
dt = create_model('dt')
# Out:
# <style  type="text/css" >
#     #T_b0c84820_abde_11ec_9124_aae9fe7ca1d0row10_col0 {
#             background:  yellow;
#         }    #T_b0c84820_abde_11ec_9124_aae9fe7ca1d0row10_col1 {
#             background:  yellow;
#         }    #T_b0c84820_abde_11ec_9124_aae9fe7ca1d0row10_col2 {
#             background:  yellow;
#         }    #T_b0c84820_abde_11ec_9124_aae9fe7ca1d0row10_col3 {
#             background:  yellow;
#         }    #T_b0c84820_abde_11ec_9124_aae9fe7ca1d0row10_col4 {
#             background:  yellow;
#         }    #T_b0c84820_abde_11ec_9124_aae9fe7ca1d0row10_col5 {
#             background:  yellow;
#         }    #T_b0c84820_abde_11ec_9124_aae9fe7ca1d0row10_col6 {
#             background:  yellow;
# ...

# %%
#trained model object is stored in the variable 'dt'. 
print(dt)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=123, splitter='best')

# %% [markdown]
# ### KNN Classifier

# %%
knn = create_model('knn')
# Out:
# <style  type="text/css" >
#     #T_b52f9bb6_abde_11ec_9124_aae9fe7ca1d0row10_col0 {
#             background:  yellow;
#         }    #T_b52f9bb6_abde_11ec_9124_aae9fe7ca1d0row10_col1 {
#             background:  yellow;
#         }    #T_b52f9bb6_abde_11ec_9124_aae9fe7ca1d0row10_col2 {
#             background:  yellow;
#         }    #T_b52f9bb6_abde_11ec_9124_aae9fe7ca1d0row10_col3 {
#             background:  yellow;
#         }    #T_b52f9bb6_abde_11ec_9124_aae9fe7ca1d0row10_col4 {
#             background:  yellow;
#         }    #T_b52f9bb6_abde_11ec_9124_aae9fe7ca1d0row10_col5 {
#             background:  yellow;
#         }    #T_b52f9bb6_abde_11ec_9124_aae9fe7ca1d0row10_col6 {
#             background:  yellow;
# ...

# %%
print(knn)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#                      weights='uniform')

# %% [markdown]
# ### Random Forests

# %%
rf = create_model('rf')
# Out:
# <style  type="text/css" >
#     #T_bc02cc2e_abde_11ec_9124_aae9fe7ca1d0row10_col0 {
#             background:  yellow;
#         }    #T_bc02cc2e_abde_11ec_9124_aae9fe7ca1d0row10_col1 {
#             background:  yellow;
#         }    #T_bc02cc2e_abde_11ec_9124_aae9fe7ca1d0row10_col2 {
#             background:  yellow;
#         }    #T_bc02cc2e_abde_11ec_9124_aae9fe7ca1d0row10_col3 {
#             background:  yellow;
#         }    #T_bc02cc2e_abde_11ec_9124_aae9fe7ca1d0row10_col4 {
#             background:  yellow;
#         }    #T_bc02cc2e_abde_11ec_9124_aae9fe7ca1d0row10_col5 {
#             background:  yellow;
#         }    #T_bc02cc2e_abde_11ec_9124_aae9fe7ca1d0row10_col6 {
#             background:  yellow;
# ...

# %%
print(rf)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=123, verbose=0,
#                        warm_start=False)

# %% [markdown]
# ### Tuning a Model
# `tune_model` automatically tunes the hyperparameters of a model using Random Grid Search on a pre-defined search space.

# %%
tuned_rf = tune_model(rf)
# Out:
# <style  type="text/css" >
#     #T_2180902c_abdf_11ec_9124_aae9fe7ca1d0row10_col0 {
#             background:  yellow;
#         }    #T_2180902c_abdf_11ec_9124_aae9fe7ca1d0row10_col1 {
#             background:  yellow;
#         }    #T_2180902c_abdf_11ec_9124_aae9fe7ca1d0row10_col2 {
#             background:  yellow;
#         }    #T_2180902c_abdf_11ec_9124_aae9fe7ca1d0row10_col3 {
#             background:  yellow;
#         }    #T_2180902c_abdf_11ec_9124_aae9fe7ca1d0row10_col4 {
#             background:  yellow;
#         }    #T_2180902c_abdf_11ec_9124_aae9fe7ca1d0row10_col5 {
#             background:  yellow;
#         }    #T_2180902c_abdf_11ec_9124_aae9fe7ca1d0row10_col6 {
#             background:  yellow;
# ...

# %% [markdown]
# ### Plotting a Model
# Before model finalization, `plot_model()` can analyze performance using AUC, confusion matrix, decision boundary, etc.
# * Takes a trained model object and returns a plot based on the test set

# %%
plot_model(tuned_rf, plot = 'auc')

# %%
plot_model(tuned_rf, plot = 'pr')

# %%
plot_model(tuned_rf, plot='feature')

# %%
plot_model(tuned_rf, plot = 'confusion_matrix')

# %% [markdown]
# Another way to analyze performance is to use `evaluate_model` to display a UI of all available plots for the model.

# %%
evaluate_model(tuned_rf)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# ### Predict on test sample
# Perform one last check by predicting on the test set and review the metrics
